# %% [markdown]
# ## Libraries

# %%
# import libraries
from fileinput import filename
from json import load
from typing import List
import string
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random
from datetime import datetime, timedelta
import numbers
from recommender_system_simple import cleaner

# %% [markdown]
# ## (ABC) Dataset

# %%
# Load data
pathABC = 'data/ABC/'
fileNamesABC = [
  'arts.pkl', 'comedy.pkl', 'documentary.pkl', 'drama.pkl', 'education.pkl', 'family.pkl', 'kids.pkl', 'movies.pkl', 'news.pkl', 'panel-discussion.pkl'
]

def loadMultiplePKLsIntoOneDF(fileNames: List[str], path: str): 
  # Load all PKL files into one dataframe
  dfs = []
  for file in fileNames:
    df = pd.read_pickle(pathABC + file)
    dfs.append(df)
  df = pd.concat(dfs, ignore_index=True)
  return df

# create dataframe from all files
dfABC = loadMultiplePKLsIntoOneDF(fileNamesABC, pathABC)

# change category column name to genre
dfABC.rename(columns={'category' : 'genre'}, inplace=True)

# clean dataframe
dfABC = cleaner(dfABC)

# save combined dataframe to a new file
dfABC.to_pickle('data/ABC/combined.pkl')
# Out:
# len big_df step 0 13885
# len big_df step 1 1014
# len big_df step 2 1014
# len big_df step 3 1014
# len big_df step 4 1014
# c:\Users\madio\Documents\UniversiteitUtrecht\Master Applied Data Science\Personalisation for (public) media\Assignment2\recommender_system_simple.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_df['tags'] = big_df['tags'].apply(correct_and_lower)
# c:\Users\madio\Documents\UniversiteitUtrecht\Master Applied Data Science\Personalisation for (public) media\Assignment2\recommender_system_simple.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_df['tags2'] = big_df['tags2'].apply(correct_and_lower)
# c:\Users\madio\Documents\UniversiteitUtrecht\Master Applied Data Science\Personalisation for (public) media\Assignment2\recommender_system_simple.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_df['deduplicated_description'] = big_df.apply(lambda x: combine_and_deduplicate(x['description'], x['description2']), axis=1)
# c:\Users\madio\Documents\UniversiteitUtrecht\Master Applied Data Science\Personalisation for (public) media\Assignment2\recommender_system_simple.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_df['deduplicated_tags'] = big_df.apply(lambda x: combine_and_deduplicate_lists_corrected(x['tags'], x['tags2']), axis=1)

# %%
# get list of dataframe columns
dfABC.to_pickle('data/ABC/combined.pkl')

dfABC.columns
# Out:
# Index(['genre', 'title', 'series', 'episode_name', 'description',
#        'description2', 'tags', 'image', 'more', 'tags2', 'publication_date',
#        'rating', 'duration_sec', 'deduplicated_description',
#        'deduplicated_tags'],
#       dtype='object')

# %% [markdown]
# ## Data exploration

# %%
# show head of dataframe of ABC dataset
dfABC[['genre', 'title', 'description', 'rating']].head()
# Out:
#     genre                          title  \
# 0  Comedy               Bangarra's World
# 1  Comedy          Mission Songs Project
# 2  Comedy  The Story of Film: An Odyssey
# 3  Comedy                     Ballet Now
# 4  Comedy   Julia Zemiro's Home Delivery
#
#                                          description rating
# 0  Join the dancers and creatives during Bangarra...      G
# 1  Jessie Lloyd's Mission Songs Project revives s...      G
# 2  A worldwide guided tour of the greatest movies...      M
# 3  This film captures the creative process behind...      M
# 4  Julia Zemiro invites notable personalities to ...      G

# %%
# dataframe dimensions
dfABC.shape
# Out:
# (13885, 13)

# %%
# descriptive statistics
dfABC.describe()
# Out:
#        category             title         series        episode_name  \
# count     13885             13885          13885               13885
# unique        9              1014            658                9400
# top        Kids  Australian Story  No data found  Series 1 Episode 1
# freq       4298               284            599                 149
#
#                                               description  \
# count                                               13885
# unique                                               1004
# top     Putting the 'real' back into reality TV, the a...
# freq                                                  284
#
#                                              description2        tags  \
# count                                               13885       13885
# unique                                              10242         175
# top     Bluey is an inexhaustible six-year-old Blue He...  [ABC Kids]
# freq                                                   50        3224
#
#                                                     image  \
# count                                               13885
# unique                                              11342
# top     https://cdn.iview.abc.net.au/thumbs/i/nu/NU222...
# freq                                                   44
#
#                              more       tags2     publication_date rating  \
# count                       13885       13885                13885  13885
# unique                        446        1712                 6020      5
# top     No more information found  [abc4kids]  2021-06-11 07:00:00      G
# freq                         9355         425                  280   8906
#
#         duration_sec
# count          13885
# unique          2528
# top              420
# freq             697

# %%
# distribution of categories
dfABC['genre'].value_counts()
# Out:
# category
# Kids                4298
# Education           2529
# Family              2056
# Drama               1175
# News                1173
# Documentary         1122
# Comedy               912
# Panel Discussion     477
# Movies               143
# Name: count, dtype: int64

# %%
# wordcloud of description column
wordcloud = WordCloud().generate(' '.join(dfABC['description']))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Create Users

# %%
# list of genres
# genres = [genre.lower() for genre in dfABC['genre'].unique()] # type: ignore
genres = dfABC['genre'].unique()

# define personas based on genres
myPersonas = {
  'comedy lover': {genre: 0.6 if genre == 'Comedy' else 0.2 for genre in genres},
  'young families': {genre: 0.8 if genre in ['Family','Kids'] else 0.3 for genre in genres},
  'information seeker': {genre: 0.9 if genre in ['News','Documentary', 'Panel Discussion', 'Education'] else 0.1 for genre in genres},
  'drama hater': {genre: 0.1 if genre == 'Drama' else 0.5 for genre in genres},
  'movie buff': {genre: 0.7 if genre == 'Movies' else 0.1 for genre in genres},
}

# %%
# functions toc reate user data based on the ABC show dataset with use of persona preferences

# set seed for all the randomisation functions
from matplotlib.style import available
from numpy import minimum


random.seed(42)


def assign_movie_languages(movies):
    movies['available_languages'] = "EN"
    return movies

movies_with_languages = assign_movie_languages(dfABC)

def selectShowForPersona(persona, selected_movies):
  preferences = myPersonas[persona]

  all_shows = list(movies_with_languages.to_dict(orient='records'))
  available_shows = [show for show in all_shows if show not in selected_movies]

  weights = [preferences[show['genre']] for show in available_shows]
  selected_movie = random.choices(available_shows, weights=weights, k=1)[0]
  return selected_movie

def randomWatchTimePercentage():
    return random.randint(30, 100)

def randomPersonaPercentageDistribution(personas):
    numberOfPersonas = len(personas)
    personasKeys = list(personas.keys())
    personaDistributionPercentage = {}
    
    # create number of random percentages for each persona
    total = 100
    minimum = 10
    for i in range(numberOfPersonas):
        percentage = random.randint(1, total - (numberOfPersonas - i - 1))
        personaDistributionPercentage[personasKeys[i]] = percentage
        total -= percentage
    
    return personaDistributionPercentage


distribution = {
    'comedy lover': 20,
    'young families': 30,
    'information seeker': 15,
    'drama hater': 10,
    'movie buff': 25,
}


def generateUsersData(numUsers=100): #set number of users here
    personaDistribution = distribution #randomPersonaPercentageDistribution(myPersonas)
    
    userData = []

    for persona, percent in personaDistribution.items():
        numPersonaUsers = int((percent / 100.0) * numUsers)
        
        for user_index in range(numPersonaUsers):
            #randomize the number of interactions (i.e. how many movies/items a user interacted with)
            numInteractions = random.randint(40, 200)  
            user_watched_movies = []
            for _ in range(numInteractions):
                movie = selectShowForPersona(persona, user_watched_movies)
                
                # add value to array so it doens't get selected again
                user_watched_movies.append(movie)
                
                if movie is None:  # Check if movie is None
                    continue  # Skip this iteration of the loop
                
                userInteraction = {
                    "user_id": f"user_{persona}_{user_index+1}",
                    "genre": movie["genre"],
                    "title": movie["title"],
                    "description": movie["description"],
                    "age_rating" : movie["rating"],
                    "duration_sec" : movie["duration_sec"],
                    "persona": persona,
                    "rating": np.nan if random.random() > 0.7 else random.randint(0, 5),
                    "watched_percentage": randomWatchTimePercentage()
                }
                userData.append(userInteraction)

    return pd.DataFrame(userData)


#generate and display the synthetic user data
userData = generateUsersData() 

# save user data to a new file
userData.to_pickle('data/ABC/userData.pkl')

# %%
combined_data = pd.read_pickle('data/ABC/combined.pkl')
# sort df on title
combined_data.sort_values(by='title', inplace=True, ignore_index=True)
combined_data.head(10)
# Out:
#        genre                                    title  \
# 0      Drama                         100 Bloody Acres
# 1      Drama                             13 Assassins
# 2  Education                        199 Little Heroes
# 3      Drama                         30 Days Of Night
# 4       News                                     7.30
# 5       News               7.30 Mark Humphries Satire
# 6       News  7.30 Special: The Shane Warne Interview
# 7       News                     7.30: The Interviews
# 8     Family                        72 Cutest Animals
# 9       News                             9/11 Stories
#
#                        series                               episode_name  \
# 0               No data found                           100 Bloody Acres
# 1               No data found                               13 Assassins
# 2           199 Little Heroes                       Series 1 Switzerland
# 3               No data found                           30 Days Of Night
# 4                        7.30                           Monday 14/3/2022
# 5  7.30 Mark Humphries Satire  Behind the scenes of the India travel ban
# 6               No data found    7.30 Special: The Shane Warne Interview
# 7        7.30: The Interviews         Dave Grohl: The Extended Interview
# 8           72 Cutest Animals   Series 1 Episode 6 Footpads and Flippers
# 9               No data found                               9/11 Stories
#
#                                          description  \
# 0  Organic fertilizer producers and brothers are ...
# 1  When the sadistic excesses of Lord Matsudaira ...
# 2  The journey to school is a very special type o...
# 3  After an Alaskan town is plunged into darkness...
# 4  Leigh Sales presents Australia's leading night...
# 5  Satirist Mark Humphries brings his unique pers...
# 6  Shane Warne has died of a suspected heart atta...
# 7  Revisit some of 7.30's most compelling convers...
# 8  The animal kingdom continually astounds us wit...
# 9  20 Years after the 9/11 Attacks, John Barron s...
#
#                                         description2  \
# 0  Organic fertilizer producers and brothers are ...
# 1  When the sadistic excesses of Lord Matsudaira ...
# 2  Enjo lives in Quinten, a forest glade in the m...
# 3  After an Alaskan town is plunged into darkness...
# 4  The devastation caused by the recent floods in...
# 5  Satirist Mark Humphries goes inside the Health...
# 6  Shane Warne has died of a suspected heart atta...
# 7  Musician Dave Grohl sits down with 7.30's Leig...
# 8  Cute is a notion that can mean many things to ...
# 9  20 Years after the 9/11 Attacks, John Barron s...
#
#                                            tags  \
# 0  [abc tv, abc tv plus, comedy, drama, movies]
# 1          [abc tv, abc tv plus, drama, movies]
# 2                           [abc me, education]
# 3          [abc tv, abc tv plus, drama, movies]
# 4                            [abc tv, abc news]
# 5                                    [abc news]
# 6                             [abc news, sport]
# 7                                    [abc news]
# 8                              [abc me, family]
# 9                            [abc news, abc tv]
#
#                                                image  \
# 0  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW297...
# 1  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW284...
# 2  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW073...
# 3  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW285...
# 4  https://cdn.iview.abc.net.au/thumbs/i/nc/NC220...
# 5  https://cdn.iview.abc.net.au/thumbs/i/nn/NN211...
# 6  https://cdn.iview.abc.net.au/thumbs/i/ns/NS188...
# 7  https://cdn.iview.abc.net.au/thumbs/i/ns/NS224...
# 8  https://cdn.iview.abc.net.au/thumbs/i/zw/ZW243...
# 9  https://cdn.iview.abc.net.au/thumbs/i/ns/NS215...
#
#                                      more  \
# 0  Director Colin Caires, Cameron Cairnes
# 1                  Director Takashi Miike
# 2               No more information found
# 3                    Director David Slade
# 4               No more information found
# 5               No more information found
# 6               No more information found
# 7               No more information found
# 8               No more information found
# 9               No more information found
#
#                                                tags2     publication_date  \
# 0  [abc1, abc2, australia, comedy, drama, film, h...  2021-06-11 07:00:00
# 1  [abc1, abc2, action, drama, film, period-drama...  2021-06-01 07:00:00
# 2  [abc3, education, environment-day, primary-hum...  2021-06-01 06:20:00
# 3  [abc1, abc2, horror, thriller, drama, film, fe...  2021-06-01 07:00:00
# 4  [news24, abc1, news, current-affairs, abc-fave...  2022-03-14 20:00:00
# 5                             [news24, news, satire]  2021-05-11 14:00:00
# 6  [news, news24, sport, shane-warne, cricket, in...  2022-03-05 02:15:00
# 7                                     [news, news24]  2022-03-08 20:00:00
# 8       [abc3, family-viewing-abcme, family-viewing]  2022-03-05 15:03:06
# 9  [news, news24, current-affairs, history, histo...  2021-09-11 20:00:11
#
#           rating duration_sec  \
# 0             MA         5207
# 1             MA         7157
# 2              G          311
# 3             MA         6471
# 4  No data found         1906
# 5  No data found          145
# 6  No data found         1470
# 7  No data found         1030
# 8              G         1616
# 9  No data found         3510
#
#                             deduplicated_description  \
# 0  brothers comes When problem. supply the radica...
# 1  When the Matsudaira action samurai deadly grou...
# 2  shared the very child's new experience What li...
# 3  townsfolk an the maniacal few band help surviv...
# 4  issues, caused analysis program, the Tingle. M...
# 5  inside India. or the Mark would government's a...
# 6  2018 the revisit aged life died Shane Thailand...
# 7  stage the politicians, Musician Nirvana Austra...
# 8  How we an the rankings seventy-two creatures o...
# 9  speaks the Barron were fateful Hear love, Atta...
#
#                                    deduplicated_tags
# 0  australia ns:relieve-boredom drama ns:be-enter...
# 1  drama action ns:be-entertained abc tv samurai ...
# 2  environment-day abc3 abc me education primary-...
# 3  drama ns:be-entertained abc tv edge-of-your-se...
# 4  current-affairs 730 news24 abc1 abc tv abc-fav...
# 5                        satire news news24 abc news
# 6  news24 australian revealing sport biography in...
# 7                               news24 news abc news
# 8  family-viewing abc3 abc me family-viewing-abcm...
# 9  somber current-affairs news24 abc1 new-york hi...

# %%
# print userdata
userData = pd.read_pickle('data/ABC/userData.pkl')
# print(userData.shape)

# give the different options of the user_id column from the userData dataframe
# print(userData['user_id'].unique())
dfABC.shape
# Out:
# (1014, 16)
